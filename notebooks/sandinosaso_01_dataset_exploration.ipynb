# %% [markdown]
# # 01 — PatchCamelyon dataset exploration
#
# Inspect shapes, class balance, and sample patches.
#
# **Prerequisite:** activate the `pathsight` pyenv environment (pinned via `.python-version`) and ensure the model package and notebook dependencies are installed:
# ```bash
# pyenv activate pathsight   # or: pyenv shell pathsight
# cd model && pip install -r requirements.txt && pip install -e . && cd ..
# pip install -r notebooks/requirements.txt
# ```
# Select the **pathsight** kernel in Jupyter before running cells.

# %%
import sys
from pathlib import Path


def _add_model_src() -> Path:
    """Walk up from CWD until we find pathsight/model/src and add it to sys.path.
    Returns the repo root (the directory that contains model/, backend/, frontend/)."""
    cwd = Path.cwd().resolve()
    for base in [cwd, *cwd.parents]:
        candidate = base / "model" / "src"
        print(f"Checking {candidate}...")
        if candidate.is_dir():
            s = str(candidate)
            if s not in sys.path:
                sys.path.insert(0, s)
            return base
    raise RuntimeError(
        f"Cannot find model/src starting from {cwd}.\n"
        "Open Jupyter from the pathsight/ repo root."
    )


REPO_ROOT = _add_model_src()
print("Repo root  :", REPO_ROOT)
print("sys.path[0]:", sys.path[0])
# Out:
# Checking /Users/sandinosaso/code/sandinosaso/pathsight/notebooks/model/src...
# Checking /Users/sandinosaso/code/sandinosaso/pathsight/model/src...
# Repo root  : /Users/sandinosaso/code/sandinosaso/pathsight
# sys.path[0]: /Users/sandinosaso/code/sandinosaso/03-Decision-Science

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from model_service.config import ModelServiceConfig
from model_service.constants import LABEL_NAMES
from model_service.preprocess.dataset_builder import build_pcam_datasets
from model_service.preprocess.tfds_pcam_loader import load_pcam_splits

print("TensorFlow:", tf.__version__)
print("Label names:", LABEL_NAMES)
# Out:
# TensorFlow: 2.16.2
# Label names: ('non_metastatic', 'metastatic')

# %%
# Downloads PCam via TFDS on first run (~7 GB); uses cached data on subsequent runs.
train_raw, val_raw, test_raw, info = load_pcam_splits(download=True)
print(info)
print("\nSplits:", info.splits)
# Out:
# tfds.core.DatasetInfo(
#     name='patch_camelyon',
#     full_name='patch_camelyon/2.0.0',
#     description="""
#     The PatchCamelyon benchmark is a new and challenging image classification
#     dataset. It consists of 327.680 color images (96 x 96px) extracted from
#     histopathologic scans of lymph node sections. Each image is annoted with a
#     binary label indicating presence of metastatic tissue. PCam provides a new
#     benchmark for machine learning models: bigger than CIFAR10, smaller than
#     Imagenet, trainable on a single GPU.
#     """,
#     homepage='https://patchcamelyon.grand-challenge.org/',
#     data_dir='/Users/sandinosaso/tensorflow_datasets/patch_camelyon/2.0.0',
#     file_format=tfrecord,
#     download_size=7.48 GiB,
#     dataset_size=7.06 GiB,
#     features=FeaturesDict({
#         'id': Text(shape=(), dtype=string),
#         'image': Image(shape=(96, 96, 3), dtype=uint8),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=2),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=32768, num_shards=8>,
#         'train': <SplitInfo num_examples=262144, num_shards=64>,
#         'validation': <SplitInfo num_examples=32768, num_shards=8>,
#     },
#     citation="""@misc{b_s_veeling_j_linmans_j_winkens_t_cohen_2018_2546921,
#       author       = {B. S. Veeling, J. Linmans, J. Winkens, T. Cohen, M. Welling},
#       title        = {Rotation Equivariant CNNs for Digital Pathology},
#       month        = sep,
#       year         = 2018,
#       doi          = {10.1007/978-3-030-00934-2_24},
#       url          = {https://doi.org/10.1007/978-3-030-00934-2_24}
#     }""",
# )
#
# Splits: {'test': <SplitInfo num_examples=32768, num_shards=8>, 'train': <SplitInfo num_examples=262144, num_shards=64>, 'validation': <SplitInfo num_examples=32768, num_shards=8>}
# 2026-04-21 12:05:32.117961: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Pro
# 2026-04-21 12:05:32.117988: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 24.00 GB
# 2026-04-21 12:05:32.117991: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 8.00 GB
# 2026-04-21 12:05:32.118017: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-04-21 12:05:32.118026: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
def count_labels(ds, steps: int = 2000):
    neg = pos = 0
    for _, y in ds.take(steps):
        if int(y.numpy()) == 1:
            pos += 1
        else:
            neg += 1
    return neg, pos

n0, n1 = count_labels(train_raw, steps=2000)
total = n0 + n1
print(f"Sample of first 2000 train examples:")
print(f"  {LABEL_NAMES[0]}: {n0} ({n0/total:.1%})")
print(f"  {LABEL_NAMES[1]}: {n1} ({n1/total:.1%})")
# Out:
# Sample of first 2000 train examples:
#   non_metastatic: 978 (48.9%)
#   metastatic: 1022 (51.1%)
# 2026-04-21 12:05:32.392843: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Visualise 8 sample patches (raw 96×96 images)
fig, axes = plt.subplots(2, 4, figsize=(12, 6))
axes = axes.ravel()
for ax, (img, lab) in zip(axes, train_raw.take(8)):
    ax.imshow(img.numpy())
    ax.set_title(LABEL_NAMES[int(lab.numpy())], fontsize=10)
    ax.axis("off")
plt.suptitle("PCam raw patches (96×96)", y=1.02)
plt.tight_layout()

out = REPO_ROOT / "artifacts" / "figures"
out.mkdir(parents=True, exist_ok=True)
fig.savefig(out / "01_sample_patches.png", dpi=150, bbox_inches="tight")
print("Saved to", out / "01_sample_patches.png")
# Out:
# Saved to /Users/sandinosaso/code/sandinosaso/pathsight/artifacts/figures/01_sample_patches.png

# %%
# Verify the full data pipeline: shapes must be (32, 224, 224, 3) and (32,)
cfg = ModelServiceConfig()
cfg.data.batch_size = 8  # small for notebook speed
train_ds, val_ds, test_ds, _ = build_pcam_datasets(cfg, download=False)
xb, yb = next(iter(train_ds))
print("Batch images :", xb.shape, "dtype", xb.dtype)
print("Batch labels :", yb.shape, "dtype", yb.dtype)
print("Pixel range  : [{:.4f}, {:.4f}]".format(float(xb.numpy().min()), float(xb.numpy().max())))
assert list(xb.shape[1:]) == [224, 224, 3], "Expected (B,224,224,3)"
assert xb.numpy().min() >= 0.0 and xb.numpy().max() <= 1.0, "Pixels not in [0,1]"
assert set(yb.numpy().astype(int).tolist()).issubset({0, 1}), "Labels not binary"
print("All assertions passed ✓")
# Out:
# 2026-04-21 12:05:35.350630: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 2026-04-21 12:05:35.350769: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 	 [[{{node EagerPyFunc}}]]
# 2026-04-21 12:05:35.352777: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 2026-04-21 12:05:35.352869: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 2026-04-21 12:05:35.353325: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 2026-04-21 12:05:35.353520: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 2026-04-21 12:05:35.353568: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 2026-04-21 12:05:35.353787: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 2026-04-21 12:05:35.355393: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 2026-04-21 12:05:35.355955: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 2026-04-21 12:05:35.356093: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 2026-04-21 12:05:35.356196: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 2026-04-21 12:05:35.356459: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 2026-04-21 12:05:35.356727: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 2026-04-21 12:05:35.356802: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# Cell In[6], line 5
#       3 cfg.data.batch_size = 8  # small for notebook speed
#       4 train_ds, val_ds, test_ds, _ = build_pcam_datasets(cfg, download=False)
# ----> 5 xb, yb = next(iter(train_ds))
#       6 print("Batch images :", xb.shape, "dtype", xb.dtype)
#       7 print("Batch labels :", yb.shape, "dtype", yb.dtype)
#
# File ~/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:809, in OwnedIterator.__next__(self)
#     807 def __next__(self):
#     808   try:
# --> 809     return self._next_internal()
#     810   except errors.OutOfRangeError:
#     811     raise StopIteration
#
# File ~/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:772, in OwnedIterator._next_internal(self)
#     769 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     770 # to communicate that there is no more data to iterate over.
#     771 with context.execution_mode(context.SYNC):
# --> 772   ret = gen_dataset_ops.iterator_get_next(
#     773       self._iterator_resource,
#     774       output_types=self._flat_output_types,
#     775       output_shapes=self._flat_output_shapes)
#     777   try:
#     778     # Fast path for the case `self._structure` is not a nested structure.
#     779     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File ~/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3086, in iterator_get_next(iterator, output_types, output_shapes, name)
#    3084   return _result
#    3085 except _core._NotOkStatusException as e:
# -> 3086   _ops.raise_from_not_ok_status(e, name)
#    3087 except _core._FallbackException:
#    3088   pass
#
# File ~/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:5983, in raise_from_not_ok_status(e, name)
#    5981 def raise_from_not_ok_status(e, name) -> NoReturn:
#    5982   e.message += (" name: " + str(name if name is not None else ""))
# -> 5983   raise core._status_to_exception(e) from None
#
# UnknownError: {{function_node __wrapped__IteratorGetNext_output_types_2_device_/job:localhost/replica:0/task:0/device:CPU:0}} ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
# Traceback (most recent call last):
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 268, in __call__
#     return func(device, token, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 146, in __call__
#     outputs = self._call(device, args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/ops/script_ops.py", line 153, in _call
#     ret = self._func(*args)
#
#   File "/Users/sandinosaso/.pyenv/versions/3.10.6/envs/pathsight/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/sandinosaso/code/sandinosaso/pathsight/model/src/model_service/preprocess/transforms.py", line 61, in _stain_normalise_tensor
#     from model_service.preprocess.transforms.stain_normalisation import normalise_pil
#
# ModuleNotFoundError: No module named 'model_service.preprocess.transforms.stain_normalisation'; 'model_service.preprocess.transforms' is not a package
#
#
# 	 [[{{node EagerPyFunc}}]] [Op:IteratorGetNext] name:
